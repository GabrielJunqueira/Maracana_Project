# %%
import pandas as pd
import geopandas as gpd
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
match_day = pd.read_csv('../../../data/data from API/match_day/hourly(20-4).csv')
match_day
# Out:
#       Unnamed: 0                   origin_id       destination_id  \
# 0              0               Leblon, (103)  STADIUM AREA, (182)
# 1              1  Lins de Vasconcelos, (105)  STADIUM AREA, (182)
# 2              2             NILÓPOLIS, (11)  STADIUM AREA, (182)
# 3              3      Marechal Hermes, (111)  STADIUM AREA, (182)
# 4              4                 Maré, (113)  STADIUM AREA, (182)
# ...          ...                         ...                  ...
# 5296        5296             Itanhangá, (91)  STADIUM AREA, (182)
# 5297        5297           Jacarepaguá, (92)  STADIUM AREA, (182)
# 5298        5298                Jacaré, (94)  STADIUM AREA, (182)
# 5299        5299       Jardim Botânico, (96)  STADIUM AREA, (182)
# 5300        5300      Jardim Guanabara, (98)  STADIUM AREA, (182)
#
#       total_trips  Arrival Hour
# 0           18.36             0
# 1           10.76             0
# 2           10.13             0
# 3           13.04             0
# ...

# %%
match_day = match_day.drop(columns=["Unnamed: 0"], axis=1)

# %% [markdown]
# ## Saving

# %%
import os
dir = '../../../data/data from API/match_day'

if not os.path.exists(dir): 
    os.makedirs(dir)
#se essa pasta não existir, crio ela

# %%
match_day.to_csv(dir + '/hourly(20-4).csv')

# %%
match_day
# Out:
#                        origin_id       destination_id  total_trips  \
# 0                  Leblon, (103)  STADIUM AREA, (182)        18.36
# 1     Lins de Vasconcelos, (105)  STADIUM AREA, (182)        10.76
# 2                NILÓPOLIS, (11)  STADIUM AREA, (182)        10.13
# 3         Marechal Hermes, (111)  STADIUM AREA, (182)        13.04
# 4                    Maré, (113)  STADIUM AREA, (182)        14.37
# ...                          ...                  ...          ...
# 5296             Itanhangá, (91)  STADIUM AREA, (182)        17.23
# 5297           Jacarepaguá, (92)  STADIUM AREA, (182)        87.06
# 5298                Jacaré, (94)  STADIUM AREA, (182)        11.10
# 5299       Jardim Botânico, (96)  STADIUM AREA, (182)        38.50
# 5300      Jardim Guanabara, (98)  STADIUM AREA, (182)        13.50
#
#       Arrival Hour
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# ...

# %%
match_day2 = match_day[match_day["origin_id"]!='STADIUM AREA, (182)']
match_day2.reset_index(inplace=True)

# %%
match_day2 = match_day2.drop(columns=["index"], axis=1)

# %%
match_day2
# Out:
#                        origin_id       destination_id  total_trips  \
# 0                  Leblon, (103)  STADIUM AREA, (182)        18.36
# 1     Lins de Vasconcelos, (105)  STADIUM AREA, (182)        10.76
# 2                NILÓPOLIS, (11)  STADIUM AREA, (182)        10.13
# 3         Marechal Hermes, (111)  STADIUM AREA, (182)        13.04
# 4                    Maré, (113)  STADIUM AREA, (182)        14.37
# ...                          ...                  ...          ...
# 2671             Itanhangá, (91)  STADIUM AREA, (182)        17.23
# 2672           Jacarepaguá, (92)  STADIUM AREA, (182)        87.06
# 2673                Jacaré, (94)  STADIUM AREA, (182)        11.10
# 2674       Jardim Botânico, (96)  STADIUM AREA, (182)        38.50
# 2675      Jardim Guanabara, (98)  STADIUM AREA, (182)        13.50
#
#       Arrival Hour
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# ...

# %%
match_day2.to_csv(dir + '/hourly(20-4).csv')
