# %%
match_day_trips = pd.read_csv('../../../data/data from API/match_day/trips(20-4).csv')
match_day_trips = match_day_trips.drop(columns=["index", "Unnamed: 0"], axis=1)

# %%
match_day_trips
# Out:
#     Arrival Hour  total_trips
# 0              0       989.49
# 1              1       639.90
# 2              2       557.16
# 3              3       509.94
# 4              4       550.36
# 5              5      1798.30
# 6              6      5912.73
# 7              7     12024.73
# 8              8     16228.70
# 9              9     14244.26
# 10            10     12173.50
# 11            11     12506.65
# 12            12     12862.88
# 13            13     13484.89
# 14            14     12735.49
# 15            15     12232.68
# 16            16     13072.73
# 17            17     16050.51
# 18            18     24316.09
# 19            19     24859.35
# 20            20     18147.75
# 21            21     12099.84
# 22            22      7214.93
# 23            23      4800.34

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a bar plot
match_day_trips.plot.bar(figsize=(18,6))
# Out:
# <AxesSubplot: xlabel='Arrival Hour'>
