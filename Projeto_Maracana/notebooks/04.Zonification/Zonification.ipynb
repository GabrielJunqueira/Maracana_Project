# %%
import pandas as pd
import geopandas as gpd
# %matplotlib inline
import osmnx as ox
import networkx as nx
from shapely.geometry import Point, LineString, Polygon
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Importing the Data

# %%
streets =  gpd.read_file('../../data/StreetNetwork/G2_edges.shp')
buildings = gpd.read_file('../../data/Buildings/buildings.geojson')
maracana = gpd.read_file('../../data/Maracana/maracana.geojson')

location_point = (-22.911667, -43.230278)
dist = 2300
parking_dist = 1000

# %%
neighborhoods = gpd.read_file('../../data/RIO DE JANEIRO MAPS/RJ-BAIRRO/RJ-BAIRRO.shp')
neighborhoods = neighborhoods.to_crs("EPSG:4326")

neighborhoods.to_file('../../data/RIO DE JANEIRO MAPS/RJ-BAIRRO/RJ-BAIRRO.shp')

# %%
rj_state = gpd.read_file('../../data/RIO DE JANEIRO MAPS/State of RJ/33MUE250GC_SIR.shp')
rj_state = rj_state.to_crs("EPSG:4326")

rj_state.to_file('../../data/RIO DE JANEIRO MAPS/State of RJ/33MUE250GC_SIR.shp')

# %% [markdown]
# # Getting just the Metropolitan Region of Rio

# %%
m_cities = ["NITERÓI",
          "SÃO GONÇALO",
          "ITABORAÍ",
          "DUQUE DE CAXIAS",
          "ITAGUAÍ",
          "SÃO JOÃO DE MERITI",
          "MAGÉ",
          "BELFORD ROXO",
          "MESQUITA",
          "JAPERI",
          "QUEIMADOS",
          "NILÓPOLIS",
          "MARICÁ",
          "NOVA IGUAÇU",
          "TANGUÁ",
          "CACHOEIRAS DE MACACU",
          "PARACAMBI",
          "GUAPIMIRIM",
          "SEROPÉDICA",
          "NOVA FRIBURGO",
          "TANGUÁ",
          "MANGARATIBA",
          "NOVA IGUAÇU"]

# %%
m_region = rj_state[rj_state['NM_MUNICIP'].isin(m_cities)]

# %%
m_region.plot(color='white', edgecolor='black', figsize=(12,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Saving

# %%
import os
dir = '../../data/RIO DE JANEIRO MAPS/metropolitan_cities'

if not os.path.exists(dir): 
    os.makedirs(dir)
#se essa pasta não existir, crio ela

# %%
m_region.to_file(dir + '/metropolitan_cities.geojson')
